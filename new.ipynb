# %% [markdown]
# #coversation;
# the coversation cant happen from string to nubers or float
# 2.There are two types conversation 2.1 explict 2.2 implict

# %%
a=65
print(str(a))
print(float(a))
print(bool(a))
#implict ex{automatically converts}
c=12
print(c/2)

# %% [markdown]
# indexing

# %%
a="suhail"
print(a[1])
print(a[-1])
#string slicing(start:stop:step)
b="suhail patan"
print(b[0:3:1])
print(b[7::12])

# %% [markdown]
# input and output

# %%
#output
print("suhail")
#formated string(writing multiple o/p in single line)
name="suhail"
age=20
print(f"my name is {name} and my age is {age}")
#input
input("What is your name")

# %% [markdown]
# Arithematic operations
# 1. python follows BODMAS

# %%
a=12
b=8
print(a+b) #addition
print(a-b) #sub
print(a*b) #mul
print(a/b) #div (quoitent)
print(a//b) #if the value is more than .5 it will round 5 to near value  FLOOR DIVISION
print(a%b) #modulo division (remainder)
print(a**b) #power

# %% [markdown]
# Assignment operations

# %%
#compound assignment operations
a=20
a=a+20
a+=20
print(a) #we can write compound assignment with arithematic operations

#COMPARISSION OPERATIONS

#six types of comparision
a=12
b=8
print(a==b) # double equal to
print(a>=b) #grather than equal to
print(a<=b) #less than equal to
print(a!=b) #not equal to
print(a>b)
print(a<b)

# %% [markdown]
# ASCII CONVERSATION
#
# 1.cant compare b/w string and integer for any coversation

# %%
#ASCII to char
a='A'
print(ord(a))

# CHAR TO ASCII
a=65
print(chr(a))

# %% [markdown]
# Logical Operators

# %%
#3 types 1.and 2.or 3. not
print(123>100 and 34==34)
print(123>100 and 34==34 and 45<90 and 12>20) #if one is false the o/p is false
print(12!=12 or 23==45 or 67==56 or 10>5) #if one is true the o/p is true
print(not 12==12) #reverse the o/p
print(True and bool(0))

# %% [markdown]
# Conditional Statements

# %%
#IF:(if the condition is true)
a=13
if a>10:
    print("I will do task A")

#IF-ELSE:(if one is true and other is false)
a=13
if a>10:
    print("I will do task A")
else:
    print("I wil do task B")
    
#IF-ELIF-ELSE:
mpney=int(input("please provide the money:"))
if mpney==10:
    print("I will do task A")
elif mpney==20:
    print("I will do task B")
else:
    print("I wil do task c")

# %% [markdown]
# Questions

# %%
#1 question
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
if n1>n2:
    print("num1 is greather number")
else:
    print("num2 is greather number")
#2 question
num=int(input("please the enter the number="))
if num%2==0:
    print("It is an even number")
else:
    print("It is an odd number")
    
#3 question
name=input("enter your name=")
age=int(input("now enter your age="))
if age>=18:
    print("hello",name,"you are a valid voter")
else:
    print("hello",name, "you are not a valid voter and the valid age above your",age)
    
#leap year
year=int(input("Enter a year="))
if (year%4==0 or year%100!=0) and year%400==0:
    print("It's a leap year")
else:
    print("not a leap year")

# %% [markdown]
# Loops in python
#
# 1.FOR LOOP
#
# 2.WHILE LOOP

# %%
#For Loop
a=range(1,20,1)

for t in a:
    print(t)
    
for t in range(21):# we should give only stop range because start and step range is setted by difault
    print(t)
# reverse
for i in range(20,51):
    print(i)
for i in range(16,1,-1):
    print(i)
for i in range(-5,-15,-1):
    print(i)
#printing table of 5
for i in range(5,51,5):
    print(i)
#printing table taking input
n=int(input("Which table you need to ptint:"))
for i in range(n,n*11,n):
    print(i)
# printing a string
a="suhail"# we should use len() because range only works for integers
for i in range(1,len(a)+1,1):
    print(i)
    
#Iterating directly over the string
a="hello suhail"
for i in a:
    print(i,end="")

#break
for i in range(1,21):
    if i==15:#(agar break chala else nai chalega and break nahi chala else chalega)
        break
    else:
        print(i)
#continue
for i in range(1,21):
    if i==15:
        continue
    else:
        print(i)
#(agar break chala else nai chalega and break nahi chala else chalega)
for i in range(1,21):
    if i==15:
        print("Break statement is excuted")
        break
    print(i)
else:
    print("Break ststement is not excuted")

# %% [markdown]
# For Loop Questions

# %%
#accept an integer and print hello world n times
n=int(input("Enter the number:"))
for i in range(1,n+1):
    print("Hello World")
#print natural number up to n
n=int(input("Enter the number:"))
for i in range(1,n+1):
     print(i)
#reverse a loop print n to 1
n=int(input())
for i in range(n,0,-1):
    print(i)
##printing a table
s=int(input("Enter a number for the table:"))
for i in range(1,11):
    print(f"{s}*{i}={i*s}")
#sum upto n terms
a=int(input("Enter the number:-"))
sum=0
for i in range(1,a+1):
    sum+=i
print(sum)
#factoiral of a number
a=int(input("Enter a number:"))
sum=1
for i in range(1,a+1):
    sum*=i
print(sum)
#print all sum of even and odd numbers in a range separetely
n=int(input("Enter the number:"))
even=0
odd=0
for i in range(1,n+1):
    if i%2==0:
        even+=i
    else:
        odd+=i
print(f"your even & odd sum are {even},{odd}")
#print all factors of a number
n=int(input("Enter the number:"))
factor=0
for i in range(1,n+1):
    if n%i==0:
        
      print(i)

#accept a number check it  is a perfect number

n=int(input("Enter the number:"))
sum=0
for i in range(1,n):
    if n%i==0:
        sum+=i
if sum==n:
    print("it's a perfect number")
else:
    print("It is not a number")
#check num is prime or not and count


n=int(input("Enter the number:"))
count=0
for i in range(1,n+1):
    if n%i==0:
        count+=i
if count==2:
    print("It's a perfect number")
else:
    print("Its not a perfect number")

#reverse a string
a="suhail"
b=a[::-1]
print(b)

#check palidrome or not
a=input("enter a word:")
b=""
for i in range(len(a)-1,-1,-1):
    b+=a[i] #upto we can write this code for reversa a string
if b==a:
    print("It is a palidrome number")
else:
    print("It is  not a palidrome number")

# %% [markdown]
# WHILE LOOP:

# %%
#seperate each digit of a num and print it on a new line
